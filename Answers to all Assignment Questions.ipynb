# %% [markdown]
# An Air Pollutant Index (API) recording system should allow user to enter the name of month to start using the system. If the user entered September, April, June, or November as the month, 30 API readings should be keyed-in by the user into the program. If user entered February, the system will ask the user to choose between leap year or non-leap year. If user choose non leap year, 28 API readings should be keyed-in into the system or else, 29 API readings will be captured. Other than that, 31 readings should be keyed-in by the user. For each API reading entered, the program should be able to analyze the condition and display the API reading with its status as per in Figure 1.

# %%
month = input('Welcome! Please enter the month: ')
month = month.lower()
def apiAnalysis(month):
    month1 = ['april', 'june','september', 'november']
    month2 = ['february']
    month3 = ['january', 'march', 'july', 'august','october','december']
    for value in month:
        if month in month1:
            valuesofmonth1 = (input(f'Enter thirty values separate by space: '))
            valuesofmonth1 = valuesofmonth1.split(' ')
            valuesofmonth1 = [float(x) for x in valuesofmonth1]
            average1 = sum(valuesofmonth1)/len(valuesofmonth1)
            return average1
        elif month in month3:
            valuesofmonth3 = (input(f'Enter thirty one values separate by space: '))
            valuesofmonth3 = valuesofmonth3.split(' ')
            valuesofmonth3 = [float(x) for x in valuesofmonth3]
            average3 = sum(valuesofmonth3)/len(valuesofmonth3)
            return average3
        else:
            leapornonleap = (input(f'Enter leap or non leap: '))
            leapornonleap = leapornonleap.lower()
            if leapornonleap == 'leap':
                valuesofmonth2 = input((f'Enter twenty nine values separate by space: '))
                valuesofmonth2 = valuesofmonth2.split(' ')
                valuesofmonth2 = [float (x) for x in valuesofmonth2]
                average2 = sum(valuesofmonth2)/len(valuesofmonth2)
                return average2
            else:
                valuesofmonthnonleap = input((f'Enter twenty eight values separate by space: '))
                valuesofmonthnonleap = valuesofmonthnonleap.split(' ')
                valuesofmonthnonleap = [float (x) for x in valuesofmonthnonleap]
                averagenl = sum(valuesofmonthnonleap)/len(valuesofmonthnonleap)
                return averagenl
apistatus = (apiAnalysis(month))
apistatus = int(apistatus)
if apistatus <= 50:
    status = 'Good'
elif apistatus <= 100:
    status = 'Moderate'
elif apistatus <=200:
    status = 'Unhealthy'
elif apistatus <= 300:
    status = 'Very Unhealthy'
else:
    status = 'Hazardous'
apiReport =[]
apiReport.append([apistatus, status])

import pandas as pd
print(pd.DataFrame(apiReport, columns = ['API','Status']))

# %% [markdown]
# ### Another Way to Solve It

# %%
print("Welcome, This program displays API reading and its status")

month1 = ['september', 'april','june','november']
month2 = ['february']
month3 = ['january','march','may','july','august','october','december']
monthtogether = ['september', 'april','june','november','february','january','march','may','july','august','october','december']
month1list = []
month2list = []
month3list = []
month = input("Enter the name of month: ")
month = month.lower()
if month in monthtogether:
    if month in month1:
        print("You are going to enter 30 API Readings")
        n =1
        for x in range(n, 30 +1):
            month1input = float(input("Enter API Reading %d: " %x))
            month1list.append(month1input)
            average = sum(month1list)/len(month1list)
    elif month in month2:
        l_or_np = input("Enter leap or non leap: ")
        l_or_np = l_or_np.lower()
        if l_or_np == "leap":
            print("You are going to enter 29 values")
            n =1
            for x in range(n, 29 +1):
                month2input = float(input("Enter API Reading %d: " %x))
                month2list.append(month2input)
                average = sum(month2list)/len(month2list)
        elif l_or_np == "non leap":
            print("You are going to enter 28 values")
            for x in range(n, 28 +1):
                month2input = float(input("Enter API Reading %d: " %x))
                month2list.append(month2input)
                average = sum(month2list)/len(month2list)
        else: 
            raise Exception("Invalid input. Check for error in spelling, space or abbreviations. Write in full")
    elif month in month3:
        print("You are going to enter 31 API Readings")
        n =1
        for x in range(n, 31 +1):
            month3input = float(input("Enter API Reading %d: " %x))
            month3list.append(month3input)
            average = sum(month3list)/len(month3list)
else:
    raise Exception("Invalid input. Check for error in spelling, space or abbreviations. Write in full")
    
average = int(average)
if average <= 50:
    status = 'Good'
    print("The API Reading is %d which shows that the status is %s."%(average, status))
elif average <= 100:
    status = 'Moderate'
    print("The API Reading is %d which shows that the status is %s."%(average, status))
elif average <=200:
    status = 'Unhealthy'
    print("The API Reading is %d which shows that the status is %s."%(average, status))
elif average <= 300:
    status = 'Very Unhealthy'
    print("The API Reading is %d which shows that the status is %s."%(average, status))
else:
    status = 'Hazardous'
    print("The API Reading is %d which shows that the status is %s."%(average, status))

# %% [markdown]
# A computer program should receive 100 men’s heights in meter, one by one from the keyboard. Do filter and display appropriate message for invalid inputs entered by user. Based on the valid input entered by user, the program should count the number of tall men and the number of short men. Any height less than or equal to 1.5 meters is considered as short. Otherwise, the man is tall. Before the program end, it should determine whether the number of short men is more than the number of tall man or vice versa.

# %%
print("Welcome, This program collects 100 men's height in meter and determines whether the number of short men is more than the number of tall men or vice versa.")
short = []
tall = []
men = []
n =1 
for x in range(n,6 +1):
    try:
        men_height = float(input("Enter the height of man %d in meters:  " %x))
    except:
        print("Invalid format entered")
    else:
        men.append(men_height)
for i in men:
    if i <=1.5:
        short.append(i)
    else:
        tall.append(i)
if len(short) == 0:
    print("There are no short men")
elif len(tall) == 0:
    print("There are no tall men")
elif len(short)>len(tall):
    print("The number of short men is more than the number of tall men ")
elif len(short)<len(tall):
    print("The number of tall men is more than the number of short men")
else:
    if len(short)==len(tall):
        print("The number of tall men is the same as the number of short men")

# %% [markdown]
# Write a simple calculator program to perform calculations MULTIPLY, DIVIDE, ADD and SUBTRACT by using function. Create a function named GET_INPUT to retrieve user input on which operation and numbers to be processed by the program.
# Note: operation MULTIPLY, DIVIDE, ADD and SUBTRACT could be in 4 different functions or all in 1 function only

# %%
# Program make a simple calculator

# This function adds two numbers
def add(x, y):
    return x + y


# This function subtracts two numbers
def subtract(x, y):
    return x - y


# This function multiplies two numbers
def multiply(x, y):
    return x * y


# This function divides two numbers
def divide(x, y):
    return x / y

print("Select operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

while True:
    # take input from the user
    choice = input("Enter choice(1/2/3/4): ")

    # check if choice is one of the four options
    if choice in ('1', '2', '3', '4'):
        num1 = float(input("Enter first number: "))
        num2 = float(input("Enter second number: "))

        if choice == '1':
            print(num1, "+", num2, "=", add(num1, num2))

        elif choice == '2':
            print(num1, "-", num2, "=", subtract(num1, num2))

        elif choice == '3':
            print(num1, "*", num2, "=", multiply(num1, num2))

        elif choice == '4':
            print(num1, "/", num2, "=", divide(num1, num2))

        # check if user wants another calculation
        # break the while loop if answer is no
        next_calculation = input("Let's do next calculation? (yes/no): ")
        if next_calculation == "no":
            break

    else:
        print("Invalid Input")
# Out:
# Select operation.
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide

# %% [markdown]
# You  are  the  system  developer  for  THive  Sdn  Bhd, which  is  famous  for  its tea  drinks  in Malaysia. You  are  to  write  a Pythonprogram  thatwillasks  the store  managerto entertype of drink, and quantity sold to their customersby using the product ID-MT01,WP01or SM01.Based  onthe  entered  type  of drink,  your  program  should  filter  for  the invalid input. By entering a validtype of drink, user should be able to enter the quantity of drinks sold according tospecified months given by the user.The program should find and  display  the biggest amount  of sales made,smallest amount of  sales made,and average amount  of  sales made based  on  quantity entered  by  the  user.For sales calculation, the pricing is set as:MT01-RM6.50,WP01-RM7.05,SM01-RM8.35 The program should allow the user to perform the process repetitively until they wish to quit.Sample of output is as below. Check diagram in WTF Folder.

# %%
print("THive Sdn Bhd Sales System")
print("----Select Drink----")
print("[MT01]Signature Brown Sugar Milk Tea")
print("[WP01]Signature Blink Blink with pearl")
print("[SM01]Smoothie with Pudding")
print('[Q]uit')

while True:
    SalesMT01 = []
    SalesWP01 = []
    SalesSM01 = []
    
    choice = input("Enter choice[MT01/WP01/SM01/Q]: ")
    if choice == "MT01":
        choiceMT01 = int(input("Enter number of months to record sales: "))
        n = 1
        for x in range(n,choiceMT01 +1):
            choiceMT012 = int (input("Enter number of cups sold for month %d: " %x))
            SalesMT01.append(choiceMT012)
    elif choice == "WP01":
        choiceWP01 = int(input("Enter number of months to record sales: "))
        n = 1
        for x in range(n,choiceWP01 +1):
            choiceWP012 = int (input("Enter number of cups sold for month %d: " %x))
            SalesWP01.append(choiceWP012)
    elif choice == "SM01":
        choiceSM01 = int(input("Enter number of months to record sales: "))
        n = 1
        for x in range(n,choiceSM01 +1):
            choiceSM012 = int(input('Enter number of cups sold for month %d: ' %x))
            SalesSM01.append(choiceSM012)
    elif choice == "Q":
        break
    else:
        print("Invalid input. Enter again. Be mindful of lowercase letters")
    if choice == "MT01":
            y = [i*6.5 for i in SalesMT01]
            average1 = (sum(y)/len(y))
            print("The biggest sales is %0.2f" %(max(y)))
            print("The smallest sales is %0.2f" %(min(y)))
            print("Average Sales from Signature Brown Sugar Milk Tea, in %d months is: %0.2f" %(choiceMT01,average1))
    elif choice == "WP01":
            g = [i*7.5 for i in SalesWP01]
            average2 = (sum(g)/len(g))
            print("The biggest sales is %0.2f" %(max(g)))
            print("The smallest sales is %0.2f" %(min(g)))
            print("Average Sales from Signature Blink Blink with Pear1, in %d months is: %0.2f" %(choiceWP01,average2))
    elif choice == "SM01":
            z = [i*8.35 for i in SalesSM01]
            average3 = (sum(z)/len(z))
            print("The biggest sales is %0.2f" %(max(z)))
            print("The smallest sales is %0.2f" %(min(z)))
            print("Average Sales from Signature Smoothie with Pudding, in %d months is: %0.2f" %(choiceSM01,average3))
# Out:
# THive Sdn Bhd Sales System
# ----Select Drink----
# [MT01]Signature Brown Sugar Milk Tea
# [WP01]Signature Blink Blink with pearl
# [SM01]Smoothie with Pudding
# [Q]uit
# Enter choice[MT01/WP01/SM01/Q]: Q
